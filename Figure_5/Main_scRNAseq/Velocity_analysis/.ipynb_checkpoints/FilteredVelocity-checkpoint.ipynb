# %%
import scanpy as sc
import anndata
from scipy import io
from scipy.sparse import coo_matrix, csr_matrix
import numpy as np
import os
import pandas as pd
import cellrank as cr
import scvelo as scv

# %%
# load sparse matrix:
X = io.mmread("counts.mtx")

# create anndata object
adata = anndata.AnnData(
    X=X.transpose().tocsr()
)

# load cell metadata:
cell_meta = pd.read_csv("metadata.csv")

# load gene names:
with open("gene_names.csv", 'r') as f:
    gene_names = f.read().splitlines()

# set anndata observations and index obs by barcodes, var by gene names
adata.obs = cell_meta
adata.obs.index = adata.obs['barcode']
adata.var.index = gene_names

# load dimensional reduction:
pca = pd.read_csv("pca.csv")
pca.index = adata.obs.index

# set pca and umap
adata.obsm['X_pca'] = pca.to_numpy()
adata.obsm['X_umap'] = np.vstack((adata.obs['UMAP_1'].to_numpy(), adata.obs['UMAP_2'].to_numpy())).T

# plot a UMAP colored by sampleID to test:
sc.pl.umap(adata, color=['RNA_snn_res.1'], frameon=False, save=True)
# Out:
# ... storing 'orig.ident' as categorical
# WARNING: saving figure to file figures/umap.pdf

# %%
# save dataset as anndata format
adata.write('my_data.h5ad')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/envs/NGS/lib/python3.8/site-packages/anndata/_io/utils.py in func_wrapper(elem, key, val, *args, **kwargs)
#     208         try:
# --> 209             return func(elem, key, val, *args, **kwargs)
#     210         except Exception as e:
#
# ~/opt/anaconda3/envs/NGS/lib/python3.8/site-packages/anndata/_io/h5ad.py in write_series(group, key, series, dataset_kwargs)
#     269     if series.dtype == object:  # Assuming it’s string
# --> 270         group.create_dataset(
#     271             key,
#
# ~/opt/anaconda3/envs/NGS/lib/python3.8/site-packages/h5py/_hl/group.py in create_dataset(self, name, shape, dtype, data, **kwds)
#     138             if name is not None:
# --> 139                 self[name] = dset
#     140             return dset
#
# ...

# %%
scv.settings.verbosity = 3
scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False)
cr.settings.verbosity = 2

# %%
ldata1 = scv.read('/Users/magalhae/Desktop/JulianscRNAseq/10-11-2021_JuliansScRNAseq_NewRef/DH-RNA-043/velocyto/DH-RNA-043.loom', cache=True, cleanup=True,sparse=True, validate=False)
ldata2 = scv.read('/Users/magalhae/Desktop/JulianscRNAseq/10-11-2021_JuliansScRNAseq_NewRef/DH-RNA-044/velocyto/DH-RNA-044.loom', cache=True, cleanup=True,sparse=True, validate=False)
ldata3 = scv.read('/Users/magalhae/Desktop/JulianscRNAseq/10-11-2021_JuliansScRNAseq_NewRef/DH-RNA-045/velocyto/DH-RNA-045.loom', cache=True, cleanup=True,sparse=True, validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
barcodes = [bc.split(':')[1] for bc in ldata1.obs.index.tolist()]
barcodes = [bc[0:len(bc)-1] + '-' + 'DH-RNA-043' for bc in barcodes]
ldata1.obs.index = barcodes

barcodes = [bc.split(':')[1] for bc in ldata2.obs.index.tolist()]
barcodes = [bc[0:len(bc)-1] + '-' + 'DH-RNA-044' for bc in barcodes]
ldata2.obs.index = barcodes

barcodes = [bc.split(':')[1] for bc in ldata3.obs.index.tolist()]
barcodes = [bc[0:len(bc)-1] + '-' + 'DH-RNA-045' for bc in barcodes]
ldata3.obs.index = barcodes

# %%
# make variable names unique
ldata1.var_names_make_unique()
ldata2.var_names_make_unique()
ldata3.var_names_make_unique()

# %%
# concatenate the three loom
ldata = ldata1.concatenate([ldata2, ldata3])

# %%
# merge matrices into the original adata object
adata2 = scv.utils.merge(adata, ldata)

# %%
# plot umap to check
sc.pl.umap(adata2, color=['RNA_snn_res.1'], frameon=False, legend_loc='on data', title='', save='_celltypes.pdf')
# Out:
# WARNING: saving figure to file figures/umap_celltypes.pdf

# %%
scv.pl.proportions(adata2, groupby='orig.ident')

# %%
# pre-process
scv.pp.filter_and_normalize(adata2)
scv.pp.moments(adata2)
# Out:
# Normalized count data: X, spliced, unspliced.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#     finished (0:00:13) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:06) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
# compute velocity
scv.tl.velocity(adata2, mode='stochastic')
scv.tl.velocity_graph(adata2)
# Out:
# computing velocities
#     finished (0:00:17) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/12 cores)
#   0%|          | 0/5765 [00:00<?, ?cells/s]
#     finished (0:02:48) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding(adata2, basis='umap', frameon=False, save='embedding.pdf')
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# saving figure to file ./figures/scvelo_embedding.pdf

# %%
scv.pl.velocity_embedding_grid(adata2, basis='umap', color=['RNA_snn_res.1'], save='embedding_grid.pdf', title='', scale=0.25)
# Out:
# saving figure to file ./figures/scvelo_embedding_grid.pdf

# %%
scv.pl.velocity_embedding_stream(adata2, basis='umap', color=['RNA_snn_res.1'], save='embedding_stream.svg', title='')
# Out:
# saving figure to file ./figures/scvelo_embedding_stream.svg

# %%
scv.pl.velocity_graph(adata2, threshold=.5, color=['RNA_snn_res.1'])

# %%
scv.tl.velocity_pseudotime(adata2)
# Out:
# computing terminal states
#     identified 0 region of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)

# %%
scv.pl.scatter(adata2, color='velocity_pseudotime', cmap='gnuplot', save='velocity_pseudotime.pdf')
# Out:
# saving figure to file ./figures/scvelo_velocity_pseudotime.pdf
